# %% [markdown]
# ### 1. Посмотреть документацию к API GitHub, разобраться как вывести список наименований репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
from pprint import pprint
import requests


url = 'https://api.github.com/users/Gzakala/repos'

response = requests.get(url)
repos = response.json()

pprint(repos)
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/GZakala/API-Python/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/GZakala/API-Python/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/GZakala/API-Python/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/GZakala/API-Python/branches{/branch}',
#   'clone_url': 'https://github.com/GZakala/API-Python.git',
#   'collaborators_url': 'https://api.github.com/repos/GZakala/API-Python/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/GZakala/API-Python/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/GZakala/API-Python/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/GZakala/API-Python/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/GZakala/API-Python/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/GZakala/API-Python/contributors',
#   'created_at': '2022-04-02T10:11:47Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/GZakala/API-Python/deployments',
#   'description': 'HomeWorks for learning the API in Python',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/GZakala/API-Python/downloads',
#   'events_url': 'https://api.github.com/repos/GZakala/API-Python/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/GZakala/API-Python/forks',
#   'full_name': 'GZakala/API-Python',
#   'git_commits_url': 'https://api.github.com/repos/GZakala/API-Python/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/GZakala/API-Python/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/GZakala/API-Python/git/tags{/sha}',
#   'git_url': 'git://github.com/GZakala/API-Python.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/GZakala/API-Python/hooks',
#   'html_url': 'https://github.com/GZakala/API-Python',
#   'id': 477017792,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/GZakala/API-Python/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/GZakala/API-Python/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/GZakala/API-Python/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/GZakala/API-Python/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/GZakala/API-Python/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/GZakala/API-Python/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/GZakala/API-Python/merges',
#   'milestones_url': 'https://api.github.com/repos/GZakala/API-Python/milestones{/number}',
#   'mirror_url': None,
#   'name': 'API-Python',
#   'node_id': 'R_kgDOHG62wA',
#   'notifications_url': 'https://api.github.com/repos/GZakala/API-Python/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/91359030?v=4',
#             'events_url': 'https://api.github.com/users/GZakala/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/GZakala/followers',
#             'following_url': 'https://api.github.com/users/GZakala/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/GZakala/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/GZakala',
#             'id': 91359030,
#             'login': 'GZakala',
#             'node_id': 'MDQ6VXNlcjkxMzU5MDMw',
#             'organizations_url': 'https://api.github.com/users/GZakala/orgs',
#             'received_events_url': 'https://api.github.com/users/GZakala/received_events',
#             'repos_url': 'https://api.github.com/users/GZakala/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/GZakala/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/GZakala/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/GZakala'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/GZakala/API-Python/pulls{/number}',
#   'pushed_at': '2022-04-02T10:11:48Z',
#   'releases_url': 'https://api.github.com/repos/GZakala/API-Python/releases{/id}',
#   'size': 0,
#   'ssh_url': 'git@github.com:GZakala/API-Python.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/GZakala/API-Python/stargazers',
#   'statuses_url': 'https://api.github.com/repos/GZakala/API-Python/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/GZakala/API-Python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/GZakala/API-Python/subscription',
#   'svn_url': 'https://github.com/GZakala/API-Python',
#   'tags_url': 'https://api.github.com/repos/GZakala/API-Python/tags',
#   'teams_url': 'https://api.github.com/repos/GZakala/API-Python/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/GZakala/API-Python/git/trees{/sha}',
#   'updated_at': '2022-04-02T10:11:47Z',
#   'url': 'https://api.github.com/repos/GZakala/API-Python',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/GZakala/db-CARS/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/GZakala/db-CARS/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/GZakala/db-CARS/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/GZakala/db-CARS/branches{/branch}',
#   'clone_url': 'https://github.com/GZakala/db-CARS.git',
#   'collaborators_url': 'https://api.github.com/repos/GZakala/db-CARS/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/GZakala/db-CARS/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/GZakala/db-CARS/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/GZakala/db-CARS/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/GZakala/db-CARS/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/GZakala/db-CARS/contributors',
#   'created_at': '2021-12-26T04:09:23Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/GZakala/db-CARS/deployments',
#   'description': 'My first project with writing my own database. The theme I '
#                  'took was the auction center of classic cars. I liked this '
#                  'topic because I found good CSV files with data and could '
#                  'practice with text processing. While writing the code '
#                  "(especially INSERT), I tried to make the most of NVIM's "
#                  'capabilities and working with files in Python. Thanks to the '
#                  'capabilities of NVIM, all the huge text and INSERT were '
#                  'edited by me in a very short time and a half, I think I will '
#                  'return to this project when I want to write my own '
#                  'mini-application with the analysis of various statistics and '
#                  'output them in a beautiful format.',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/GZakala/db-CARS/downloads',
#   'events_url': 'https://api.github.com/repos/GZakala/db-CARS/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/GZakala/db-CARS/forks',
#   'full_name': 'GZakala/db-CARS',
#   'git_commits_url': 'https://api.github.com/repos/GZakala/db-CARS/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/GZakala/db-CARS/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/GZakala/db-CARS/git/tags{/sha}',
#   'git_url': 'git://github.com/GZakala/db-CARS.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/GZakala/db-CARS/hooks',
#   'html_url': 'https://github.com/GZakala/db-CARS',
#   'id': 441806454,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/GZakala/db-CARS/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/GZakala/db-CARS/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/GZakala/db-CARS/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/GZakala/db-CARS/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/GZakala/db-CARS/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/GZakala/db-CARS/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/GZakala/db-CARS/merges',
#   'milestones_url': 'https://api.github.com/repos/GZakala/db-CARS/milestones{/number}',
#   'mirror_url': None,
#   'name': 'db-CARS',
#   'node_id': 'R_kgDOGlVudg',
#   'notifications_url': 'https://api.github.com/repos/GZakala/db-CARS/notifications{?since,all,participating}',
#   'open_issues': 1,
#   'open_issues_count': 1,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/91359030?v=4',
#             'events_url': 'https://api.github.com/users/GZakala/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/GZakala/followers',
#             'following_url': 'https://api.github.com/users/GZakala/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/GZakala/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/GZakala',
#             'id': 91359030,
#             'login': 'GZakala',
#             'node_id': 'MDQ6VXNlcjkxMzU5MDMw',
#             'organizations_url': 'https://api.github.com/users/GZakala/orgs',
#             'received_events_url': 'https://api.github.com/users/GZakala/received_events',
#             'repos_url': 'https://api.github.com/users/GZakala/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/GZakala/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/GZakala/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/GZakala'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/GZakala/db-CARS/pulls{/number}',
#   'pushed_at': '2021-12-26T04:26:29Z',
#   'releases_url': 'https://api.github.com/repos/GZakala/db-CARS/releases{/id}',
#   'size': 168,
#   'ssh_url': 'git@github.com:GZakala/db-CARS.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/GZakala/db-CARS/stargazers',
#   'statuses_url': 'https://api.github.com/repos/GZakala/db-CARS/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/GZakala/db-CARS/subscribers',
#   'subscription_url': 'https://api.github.com/repos/GZakala/db-CARS/subscription',
#   'svn_url': 'https://github.com/GZakala/db-CARS',
#   'tags_url': 'https://api.github.com/repos/GZakala/db-CARS/tags',
#   'teams_url': 'https://api.github.com/repos/GZakala/db-CARS/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/GZakala/db-CARS/git/trees{/sha}',
#   'updated_at': '2021-12-26T04:13:04Z',
#   'url': 'https://api.github.com/repos/GZakala/db-CARS',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/GZakala/python-Lessons/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/GZakala/python-Lessons/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/GZakala/python-Lessons/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/GZakala/python-Lessons/branches{/branch}',
#   'clone_url': 'https://github.com/GZakala/python-Lessons.git',
#   'collaborators_url': 'https://api.github.com/repos/GZakala/python-Lessons/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/GZakala/python-Lessons/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/GZakala/python-Lessons/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/GZakala/python-Lessons/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/GZakala/python-Lessons/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/GZakala/python-Lessons/contributors',
#   'created_at': '2021-09-25T03:50:19Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/GZakala/python-Lessons/deployments',
#   'description': 'homework for python',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/GZakala/python-Lessons/downloads',
#   'events_url': 'https://api.github.com/repos/GZakala/python-Lessons/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/GZakala/python-Lessons/forks',
#   'full_name': 'GZakala/python-Lessons',
#   'git_commits_url': 'https://api.github.com/repos/GZakala/python-Lessons/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/GZakala/python-Lessons/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/GZakala/python-Lessons/git/tags{/sha}',
#   'git_url': 'git://github.com/GZakala/python-Lessons.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/GZakala/python-Lessons/hooks',
#   'html_url': 'https://github.com/GZakala/python-Lessons',
#   'id': 410168480,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/GZakala/python-Lessons/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/GZakala/python-Lessons/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/GZakala/python-Lessons/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/GZakala/python-Lessons/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/GZakala/python-Lessons/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/GZakala/python-Lessons/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/GZakala/python-Lessons/merges',
#   'milestones_url': 'https://api.github.com/repos/GZakala/python-Lessons/milestones{/number}',
#   'mirror_url': None,
#   'name': 'python-Lessons',
#   'node_id': 'R_kgDOGHKsoA',
#   'notifications_url': 'https://api.github.com/repos/GZakala/python-Lessons/notifications{?since,all,participating}',
#   'open_issues': 2,
#   'open_issues_count': 2,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/91359030?v=4',
#             'events_url': 'https://api.github.com/users/GZakala/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/GZakala/followers',
#             'following_url': 'https://api.github.com/users/GZakala/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/GZakala/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/GZakala',
#             'id': 91359030,
#             'login': 'GZakala',
#             'node_id': 'MDQ6VXNlcjkxMzU5MDMw',
#             'organizations_url': 'https://api.github.com/users/GZakala/orgs',
#             'received_events_url': 'https://api.github.com/users/GZakala/received_events',
#             'repos_url': 'https://api.github.com/users/GZakala/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/GZakala/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/GZakala/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/GZakala'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/GZakala/python-Lessons/pulls{/number}',
#   'pushed_at': '2021-10-05T10:40:47Z',
#   'releases_url': 'https://api.github.com/repos/GZakala/python-Lessons/releases{/id}',
#   'size': 12,
#   'ssh_url': 'git@github.com:GZakala/python-Lessons.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/GZakala/python-Lessons/stargazers',
#   'statuses_url': 'https://api.github.com/repos/GZakala/python-Lessons/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/GZakala/python-Lessons/subscribers',
#   'subscription_url': 'https://api.github.com/repos/GZakala/python-Lessons/subscription',
#   'svn_url': 'https://github.com/GZakala/python-Lessons',
#   'tags_url': 'https://api.github.com/repos/GZakala/python-Lessons/tags',
#   'teams_url': 'https://api.github.com/repos/GZakala/python-Lessons/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/GZakala/python-Lessons/git/trees{/sha}',
#   'updated_at': '2021-09-28T14:57:56Z',
#   'url': 'https://api.github.com/repos/GZakala/python-Lessons',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/branches{/branch}',
#   'clone_url': 'https://github.com/GZakala/python_ml_libraries.git',
#   'collaborators_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/contributors',
#   'created_at': '2022-01-15T19:48:29Z',
#   'default_branch': 'main',
#   'deployments_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/deployments',
#   'description': 'This is a repository with homework on topics such as: Numpy, '
#                  'Pandas, Scikit-learn, Matplotlib, Seaborn',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/downloads',
#   'events_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/forks',
#   'full_name': 'GZakala/python_ml_libraries',
#   'git_commits_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/git/tags{/sha}',
#   'git_url': 'git://github.com/GZakala/python_ml_libraries.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/hooks',
#   'html_url': 'https://github.com/GZakala/python_ml_libraries',
#   'id': 448375746,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/merges',
#   'milestones_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/milestones{/number}',
#   'mirror_url': None,
#   'name': 'python_ml_libraries',
#   'node_id': 'R_kgDOGrmrwg',
#   'notifications_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/91359030?v=4',
#             'events_url': 'https://api.github.com/users/GZakala/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/GZakala/followers',
#             'following_url': 'https://api.github.com/users/GZakala/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/GZakala/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/GZakala',
#             'id': 91359030,
#             'login': 'GZakala',
#             'node_id': 'MDQ6VXNlcjkxMzU5MDMw',
#             'organizations_url': 'https://api.github.com/users/GZakala/orgs',
#             'received_events_url': 'https://api.github.com/users/GZakala/received_events',
#             'repos_url': 'https://api.github.com/users/GZakala/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/GZakala/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/GZakala/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/GZakala'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/pulls{/number}',
#   'pushed_at': '2022-02-08T17:04:33Z',
#   'releases_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/releases{/id}',
#   'size': 4311,
#   'ssh_url': 'git@github.com:GZakala/python_ml_libraries.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/stargazers',
#   'statuses_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/subscribers',
#   'subscription_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/subscription',
#   'svn_url': 'https://github.com/GZakala/python_ml_libraries',
#   'tags_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/tags',
#   'teams_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/GZakala/python_ml_libraries/git/trees{/sha}',
#   'updated_at': '2022-01-15T19:58:31Z',
#   'url': 'https://api.github.com/repos/GZakala/python_ml_libraries',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/GZakala/spec_explanation/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/GZakala/spec_explanation/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/GZakala/spec_explanation/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/GZakala/spec_explanation/branches{/branch}',
#   'clone_url': 'https://github.com/GZakala/spec_explanation.git',
#   'collaborators_url': 'https://api.github.com/repos/GZakala/spec_explanation/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/GZakala/spec_explanation/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/GZakala/spec_explanation/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/GZakala/spec_explanation/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/GZakala/spec_explanation/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/GZakala/spec_explanation/contributors',
#   'created_at': '2022-01-23T20:17:34Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/GZakala/spec_explanation/deployments',
#   'description': 'Experiments for habr article',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/GZakala/spec_explanation/downloads',
#   'events_url': 'https://api.github.com/repos/GZakala/spec_explanation/events',
#   'fork': True,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/GZakala/spec_explanation/forks',
#   'full_name': 'GZakala/spec_explanation',
#   'git_commits_url': 'https://api.github.com/repos/GZakala/spec_explanation/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/GZakala/spec_explanation/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/GZakala/spec_explanation/git/tags{/sha}',
#   'git_url': 'git://github.com/GZakala/spec_explanation.git',
#   'has_downloads': True,
#   'has_issues': False,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': '',
#   'hooks_url': 'https://api.github.com/repos/GZakala/spec_explanation/hooks',
#   'html_url': 'https://github.com/GZakala/spec_explanation',
#   'id': 451220270,
#   'is_template': False,
#   'issue_comment_url': 'https://api.github.com/repos/GZakala/spec_explanation/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/GZakala/spec_explanation/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/GZakala/spec_explanation/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/GZakala/spec_explanation/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/GZakala/spec_explanation/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/GZakala/spec_explanation/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/GZakala/spec_explanation/merges',
#   'milestones_url': 'https://api.github.com/repos/GZakala/spec_explanation/milestones{/number}',
#   'mirror_url': None,
#   'name': 'spec_explanation',
#   'node_id': 'R_kgDOGuUTLg',
#   'notifications_url': 'https://api.github.com/repos/GZakala/spec_explanation/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/91359030?v=4',
#             'events_url': 'https://api.github.com/users/GZakala/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/GZakala/followers',
#             'following_url': 'https://api.github.com/users/GZakala/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/GZakala/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/GZakala',
#             'id': 91359030,
#             'login': 'GZakala',
#             'node_id': 'MDQ6VXNlcjkxMzU5MDMw',
#             'organizations_url': 'https://api.github.com/users/GZakala/orgs',
#             'received_events_url': 'https://api.github.com/users/GZakala/received_events',
#             'repos_url': 'https://api.github.com/users/GZakala/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/GZakala/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/GZakala/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/GZakala'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/GZakala/spec_explanation/pulls{/number}',
#   'pushed_at': '2019-11-13T18:50:41Z',
#   'releases_url': 'https://api.github.com/repos/GZakala/spec_explanation/releases{/id}',
#   'size': 2813,
#   'ssh_url': 'git@github.com:GZakala/spec_explanation.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/GZakala/spec_explanation/stargazers',
#   'statuses_url': 'https://api.github.com/repos/GZakala/spec_explanation/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/GZakala/spec_explanation/subscribers',
#   'subscription_url': 'https://api.github.com/repos/GZakala/spec_explanation/subscription',
#   'svn_url': 'https://github.com/GZakala/spec_explanation',
#   'tags_url': 'https://api.github.com/repos/GZakala/spec_explanation/tags',
#   'teams_url': 'https://api.github.com/repos/GZakala/spec_explanation/teams',
#   'topics': [],
#   'trees_url': 'https://api.github.com/repos/GZakala/spec_explanation/git/trees{/sha}',
#   'updated_at': '2019-11-13T18:50:43Z',
#   'url': 'https://api.github.com/repos/GZakala/spec_explanation',
#   'visibility': 'public',
#   'watchers': 0,
#   'watchers_count': 0}]

# %% [markdown]
# ### 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
url = 'https://api.vk.com/method/groups.get'

params = {
    'user_id': '664175823',
    'access_token': '71447db5055cbcbf22b81a85b4ed15c5d83f3993eb711ec7e3e7a7d9ca5b107259205db602bf262be04f7',
    'v': '5.81'
}

response = requests.get(url, params=params)
groups = response.json()

pprint(groups)
# Out:
# {'response': {'count': 7,
#               'items': [42968101,
#                         22798006,
#                         169934613,
#                         90767168,
#                         50931475,
#                         102018175,
#                         149653987]}}
