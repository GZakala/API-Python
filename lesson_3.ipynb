# %% [markdown]
# ## 1. Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы (необходимо анализировать оба поля зарплаты).

# %%
import re
import requests
from hashlib import md5
from pymongo import MongoClient
from pymongo.errors import DuplicateKeyError
from pprint import pprint
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ### Функция для создания DOM из необходимой html страницы

# %%
def get_dom(vacancy, page=0):
    url_base = 'https://hh.ru/vacancies/'
    
    if vacancy is None:
        vacancy = input('Введите желаемую вакансию: ')

    url = url_base + vacancy

    params = {'page': str(page)}

    headers = {'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.174 YaBrowser/22.1.3.907 (beta) Yowser/2.5 Safari/537.36'}

    response = requests.get(
        url,
        params=params,
        headers=headers
    )

    dom = bs(response.text, 'html.parser')
    
    return dom

# %% [markdown]
# ### Отдельно создадим функцию, генерирующюю хэш на основе вводимой информации, в эту функцию мы будем передавать список-документ
# ### Возвращаемый хэш используем в качестве id этого документа, таким образом мы исключим дубликаты в нашей базе данных

# %%
def hash_id(doc):
    bytes_input = str(doc).encode('utf-8')
    
    return md5(bytes_input).hexdigest()

# %% [markdown]
# ### Функция для добавления новой информации, взятой из DOM

# %%
def load_vacancies(dom, mongo_collection, duplicate_info=False, website='https://hh.ru'):
    
    vacancies = dom.find_all('div', {'class': 'vacancy-serp-item-body__main-info'})
    if vacancies == []:
        if duplicate_info:
            return (0, 0)
        else:
            return 0
    
    num_added = 0
    duplicates = 0
    
    for vacancy in vacancies:
        new_vacancy = {}
        
        # Добавление поля name
        name = vacancy.find('a').getText()
        new_vacancy['name'] = name
        
        # Добавление полей min_salary и max_salary
        salary = vacancy.find('span', {'class': 'bloko-header-section-3'})
        if salary:
            salary = salary.getText().replace('\u202f', '')
        
        # Среди этих записей часто используется длинное тире, которого нет на обычной раскладке клавиатуры
        # Его номер в таблице ascii 8211б, потому я, также, добавил его сюда
        if salary is None:
            min_salary = None
            max_salary = None
        elif ('от' in salary and 'до' in salary) or '-' in salary or chr(8211) in salary:
            min_salary = int( re.search(r'\d+', salary)[0] )
            max_salary = int( re.findall(r'\d+', salary)[1] )
        elif 'от' in salary:
            min_salary = int( re.search(r'\d+', salary)[0] )
            max_salary = None
        elif 'до' in salary:
            min_salary = None
            max_salary = int( re.search(r'\d+', salary)[0] )
        
        new_vacancy['min_salary'] = min_salary
        new_vacancy['max_salary'] = max_salary
        
        # Добавление поля currency
        if salary:
            currency = re.search(r'[A-zА-я]{3}', salary)[0]
        else:
            currency = None
        
        new_vacancy['currency'] = currency
        
        # Добавление поля link
        link = vacancy.find('a')['href']
        new_vacancy['link'] = link
        
        # Добавление поля website
        new_vacancy['website'] = website
        
        # Добавление поля _id
        _id = hash_id(new_vacancy)
        new_vacancy['_id'] = _id
        
        # Добавление документа в базу данных
        try:
            mongo_collection.insert_one(new_vacancy)
            num_added += 1
        except DuplicateKeyError:
            duplicates += 1
    
    if duplicate_info:
        return (num_added, duplicates)
    else:
        return num_added

# %% [markdown]
# ### Что бы выбрать нужную вакансию, придется вписать ее в нужной строке
# ### Это нужно для создания коллекции, специально под эту вакансию
# ### Также нужно будет ввести в поле ввода точно такое же значение

# %%
vacancy = input('Введите желаемую вакансию на английском языке: ').replace(' ', '-')

client = MongoClient('127.0.0.1', 27017)
db = client['user']
collection = db.stroitel        # <--- Допишите вакансию здесь, к примеру "db.stroitel"

vac_added = 0
dup_finded = 0

for i in range(40):
    print(f'{i+1} страница')
    dom = get_dom(vacancy, i)
    vacancy_info = load_vacancies(dom, collection, duplicate_info=True)
    
    
    if vacancy_info[0] == 0 and vacancy_info[1] == 0:
        break
        
    vac_added += vacancy_info[0]
    dup_finded += vacancy_info[1]
    
    
print()
print(f'Вакансий добавлено: {vac_added}')
print(f'Дубликатов обнаружено: {dup_finded}')
# Out:
# Введите желаемую вакансию на английском языке: stroitel
# 1 страница
# 2 страница
# 3 страница
# 4 страница
# 5 страница
# 6 страница
# 7 страница
# 8 страница
# 9 страница
# 10 страница
# 11 страница
#
# Вакансий добавлено: 76
# Дубликатов обнаружено: 406

# %%
result = list(collection.find({}))

for i in range(3):
    pprint(result[i])
    print()
# Out:
# {'_id': '152e7e98097da3a3e1e1eeead768c86b',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54534809?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 100000,
#  'min_salary': 90000,
#  'name': 'Водитель / Разнорабочий-строитель',
#  'website': 'https://hh.ru'}
#
# {'_id': '8a5d6e5a7598022e5a0e23222d9398da',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54519579?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 130000,
#  'min_salary': None,
#  'name': 'Инженер-строитель',
#  'website': 'https://hh.ru'}
#
# {'_id': 'ad39e4c77ff9dfd1d163b3729b387d2c',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53562072?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 250000,
#  'min_salary': 80000,
#  'name': 'Инженер-строитель',
#  'website': 'https://hh.ru'}

# %% [markdown]
# ## 2. Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы (необходимо анализировать оба поля зарплаты).
#
# ### Сначала я использую проверку на минимальную зарплату, а потом на максимальную. Это нужно на случай, если в поле минимальной зарплаты будет None

# %%
salary = int(input('Введите желаемую заработную плату: '))

select = {
    '$or':
         [{'min_salary': {'$gt': salary}},
          {'max_salary': {'%gt': salary}}]
}

for vac in collection.find(select):
    print()
    pprint(vac)
# Out:
# Введите желаемую заработную плату: 100000
#
# {'_id': 'dd629f62c12b1a363c55da8c7bc98eee',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53409278?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 104000,
#  'name': 'Инженер-строитель/Ведущий специалист по техническому надзору',
#  'website': 'https://hh.ru'}
#
# {'_id': '028fde6317f841266223041e1faf6aae',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53618780?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 180000,
#  'min_salary': 130000,
#  'name': 'Монтажник НВК',
#  'website': 'https://hh.ru'}
#
# {'_id': 'f6c5afb76a556fe26f55e5507629e8c9',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54500719?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 150000,
#  'name': 'Начальник участка',
#  'website': 'https://hh.ru'}
#
# {'_id': '62c7ad9ea45fd7ede32db102b256c294',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54500707?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 200000,
#  'name': 'Руководитель проекта',
#  'website': 'https://hh.ru'}
#
# {'_id': '2985df7635d93313104d87383db41c26',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54156487?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 150000,
#  'min_salary': 120000,
#  'name': 'Начальник участка строительно-монтажных работ (Благоустройство)',
#  'website': 'https://hh.ru'}
#
# {'_id': 'a85a1a4733815f214ec72057e626c646',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54419197?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 110000,
#  'name': 'Начальник строительного участка',
#  'website': 'https://hh.ru'}
#
# {'_id': '26d80940df5b6c6feeb6e6ad6e3e4959',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/50285420?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 180000,
#  'min_salary': 120000,
#  'name': 'Инженер-строитель (проектировщик)',
#  'website': 'https://hh.ru'}
#
# {'_id': 'a9af4e83f56ef30903c34433de5f2f15',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53181776?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Архитектор (малоэтажное строительство)',
#  'website': 'https://hh.ru'}
#
# {'_id': '6edb8f93d992dee6affb86b5bc08e158',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54323658?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 115000,
#  'name': 'Инженер-строитель',
#  'website': 'https://hh.ru'}
#
# {'_id': 'fd1158aad7e29d3944b49f52edb21fa0',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/48618393?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 180000,
#  'min_salary': 120000,
#  'name': 'Инженер-строитель',
#  'website': 'https://hh.ru'}
#
# {'_id': '1f7001d2bad0122d3240d4a408390e02',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53683849?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 120000,
#  'min_salary': 120000,
#  'name': 'Архитектор',
#  'website': 'https://hh.ru'}
#
# {'_id': '0601aca2f493e99d62a04b69897a1491',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54287171?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 150000,
#  'name': 'Менеджер проектных продаж',
#  'website': 'https://hh.ru'}
#
# {'_id': 'c68b5a1242d01cc46717978a7024e881',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54497351?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 500000,
#  'min_salary': 200000,
#  'name': 'Менеджер по продажам домов по технологии фахверк (клееный брус)',
#  'website': 'https://hh.ru'}
#
# {'_id': 'f54c05141c9829286ca9d58b4a81e5f4',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53697344?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 200000,
#  'name': 'Главный инженер проекта (ГИП) Комплексный/Главный инженер проекта '
#          '(Проектирование и строительство)',
#  'website': 'https://hh.ru'}
#
# {'_id': '5c49215fa022348a4c195177c9cc8ab7',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53392741?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 160000,
#  'min_salary': 125000,
#  'name': 'Инженер-конструктор ПГС (КЖ,КМ) / Прочнист /BIM',
#  'website': 'https://hh.ru'}
#
# {'_id': '93a4b30db7e66c41809d2d90df1fd6fe',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54287214?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 200000,
#  'name': 'Руководитель отдела проектных продаж',
#  'website': 'https://hh.ru'}
#
# {'_id': '69927a51aec5903dba2ff7c8cc636a76',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53854421?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 250000,
#  'min_salary': 120000,
#  'name': 'Менеджер по продажам инвестиционного продукта (недвижимость)',
#  'website': 'https://hh.ru'}
#
# {'_id': '2fbc162d5b55bb271e0999c9d2e45c23',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53417827?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 200000,
#  'min_salary': 200000,
#  'name': 'Менеджер по продажам',
#  'website': 'https://hh.ru'}
#
# {'_id': 'bbf62c4de0dd9da7bae5730e0f505c13',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54290479?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 300000,
#  'min_salary': 150000,
#  'name': 'Исполнительный директор (Консалтинг СРО)',
#  'website': 'https://hh.ru'}
#
# {'_id': 'f09d49a78bc21d6997bd68ab544b89c9',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53378701?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 130000,
#  'name': 'Начальник склада',
#  'website': 'https://hh.ru'}
#
# {'_id': '9918cd0922ababfe871cf8fa32ff594d',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54375858?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 130000,
#  'name': 'Инженер-сметчик (ценообразование)',
#  'website': 'https://hh.ru'}
#
# {'_id': '0f5a136f92910333a2b3e05371587462',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54509387?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 150000,
#  'name': 'Категорийный менеджер \\ Менеджер отдела закупок (торговое '
#          'оборудование)',
#  'website': 'https://hh.ru'}
#
# {'_id': '1a60a457a03e0df52ce092eb3048dccf',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54377394?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 130000,
#  'name': 'Экономист по проектам',
#  'website': 'https://hh.ru'}
#
# {'_id': 'f2d52635aa945728b73085370119cf91',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53585198?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Аналитик',
#  'website': 'https://hh.ru'}
#
# {'_id': '4aef5ff2855b04a9a1aed7392f8ac87a',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/50723123?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 200000,
#  'name': 'Менеджер по работе с ключевыми клиентами/ КАМ',
#  'website': 'https://hh.ru'}
#
# {'_id': '5e67a47cfea79847f6df9cacbf1b7971',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54427045?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 105000,
#  'name': 'Главный инженер',
#  'website': 'https://hh.ru'}
#
# {'_id': '8a319689ac6272959f3ae74d3673d3fa',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54330269?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 150000,
#  'name': 'Начальник отдела подготовки проектной документации',
#  'website': 'https://hh.ru'}
#
# {'_id': '9d187faa4a1ecfa25db611ed0b99fe0b',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54374036?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 172000,
#  'min_salary': 140000,
#  'name': 'Руководитель ПТО',
#  'website': 'https://hh.ru'}
#
# {'_id': 'c2db914e70db77413edb73518304deff',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54330540?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 150000,
#  'min_salary': 120000,
#  'name': 'Начальник участка по внутренним инженерным сетям',
#  'website': 'https://hh.ru'}
#
# {'_id': '527ba656b6c0967d7a182df316c23027',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54330111?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 150000,
#  'min_salary': 110000,
#  'name': 'Инженер ОВ и ВК',
#  'website': 'https://hh.ru'}
#
# {'_id': 'b7791a9256bed831fc2fb5b7c950dba7',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/51096044?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 150000,
#  'name': 'Руководитель направления инженерных систем (механические системы)',
#  'website': 'https://hh.ru'}
#
# {'_id': 'ef78c3924d6ae115292a9fc9be366a6b',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54322260?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Менеджер в отдел закупок (DIY, посуда, инструмент, хозяйственные '
#          'товары, товары для дома)',
#  'website': 'https://hh.ru'}
#
# {'_id': '1850dd91569078cf243543db8231a9ce',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54204246?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 115000,
#  'name': 'Главный специалист строительного отдела (КОНСТРУКТОР-ПРОЕКТИРОВЩИК '
#          '(КЖ, КМ, КМД)',
#  'website': 'https://hh.ru'}
#
# {'_id': 'f2a7a91d1f518686609058644dca0f39',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53084262?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 183950,
#  'min_salary': 141500,
#  'name': 'Начальник строительной лаборатории',
#  'website': 'https://hh.ru'}
#
# {'_id': '51db6cac76ad61f2af4a26376a53f4aa',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/48983222?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 140000,
#  'min_salary': 140000,
#  'name': 'Ведущий инженер по качеству проектирования (ОВ и ВК)',
#  'website': 'https://hh.ru'}
#
# {'_id': '8d17dafc6718daeb0bb0fe7d16cfddd8',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/50161954?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Менеджер по объектным продажам / Руководитель проектов / продажи '
#          'оборудования',
#  'website': 'https://hh.ru'}
#
# {'_id': '5626263f65a27f41534f0b3a1a1521ab',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/52258044?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 150000,
#  'name': 'Категорийный менеджер \\ Менеджер отдела закупок (офисная мебель)',
#  'website': 'https://hh.ru'}
#
# {'_id': '82e7ef1665f64eae39c560eaea0fbc37',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53624272?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 140000,
#  'name': 'Дизайнер интерьеров (общественные пространства)',
#  'website': 'https://hh.ru'}
#
# {'_id': '1b3bfeab20ecf928a316657a2b454159',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53618533?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 147000,
#  'name': 'Заместитель главного инженера в Бангладеш',
#  'website': 'https://hh.ru'}
#
# {'_id': 'f48e7aa35b78de36d2f9a2d878e120bd',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53681699?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Менеджер отдела региональных продаж',
#  'website': 'https://hh.ru'}
#
# {'_id': '1d75b037728940adb365080236f61a4f',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/50995394?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 250000,
#  'name': 'Директор службы единого заказчика (Девелопмент)',
#  'website': 'https://hh.ru'}
#
# {'_id': '74e353ff1cd35fe6524932f379f9f1e5',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53321992?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 150000,
#  'name': 'Программист 1С',
#  'website': 'https://hh.ru'}
#
# {'_id': '071386bafd2686f11a1bb81054bc83fe',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/49058205?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Руководитель направления фасадных систем',
#  'website': 'https://hh.ru'}
#
# {'_id': '8fe36ade5ffa2aad6fda180da47eee48',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54539093?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Ведущий инженер',
#  'website': 'https://hh.ru'}
#
# {'_id': '33928bf6a26c9a8b434dbeb4eba21dd7',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54569997?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 111000,
#  'name': 'Ведущий инженер-сметчик',
#  'website': 'https://hh.ru'}
#
# {'_id': '9bf717e54df61a630a0c3a8d44a4c417',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54561618?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 110000,
#  'name': 'Инженер-проектировщик систем электроснабжения и автоматики / '
#          'проектов Умный Дом',
#  'website': 'https://hh.ru'}
#
# {'_id': '125de2ac0a71b92aa7c41422c938f14e',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54570076?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Программист 1 С',
#  'website': 'https://hh.ru'}
#
# {'_id': 'ce317a1791f4572e0b1d21cbdf7b4a6f',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/54601286?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': None,
#  'min_salary': 120000,
#  'name': 'Тестировщик ПО',
#  'website': 'https://hh.ru'}
#
# {'_id': '7a447c2297e832cef71962e055e1bc57',
#  'currency': 'руб',
#  'link': 'https://hh.ru/vacancy/53817397?query=%D1%81%D1%82%D1%80%D0%BE%D0%B8%D1%82%D0%B5%D0%BB%D1%8C',
#  'max_salary': 180000,
#  'min_salary': 150000,
#  'name': 'Главный инженер по эксплуатации',
#  'website': 'https://hh.ru'}
